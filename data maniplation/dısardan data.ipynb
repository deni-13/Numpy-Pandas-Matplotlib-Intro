# %%
import pandas as pd

# %%
pd.read_csv("ty.csv")
# Out:
#                                                                                Kategori: Tüm kategoriler
# Zaman         Taylor Swift: (Amerika Birleşik Devletleri)  Kim Kardashian: (Amerika Birleşik Devletleri)
# 2021-05-11T02 43                                                                                      49
# 2021-05-11T03 45                                                                                      51
# 2021-05-11T04 47                                                                                      50
# 2021-05-11T05 51                                                                                      57
# ...                                                                                                  ...
# 2021-05-17T21 33                                                                                      38
# 2021-05-17T22 33                                                                                      36
# ...

# %%
 #burda taylor swift ve kim kardashian karsılastırılıyor...

# %%
#excel,txt gibi dosyaları okuabiliyoruz.
