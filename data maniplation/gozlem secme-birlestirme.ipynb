# %% [markdown]
# ## Gozlem Ve Degisken Secimi

# %%
import numpy as np
import pandas as pd
m=np.random.randint(1,30,size=(10,3))
df=pd.DataFrame(m,columns=["var1","var2","var3"])
df
# Out:
#    var1  var2  var3
# 0     3    20    27
# 1    11     3    13
# 2    25    18    21
# 3    20    20    18
# 4    13    17    22
# 5    24     2    21
# 6    28    27     3
# 7     4    14    15
# 8     3    11    27
# 9     2    27    18

# %%
#loc---> secim yapmak icin

# %%
df.loc[0:3] #3ude alıyor
# Out:
#    var1  var2  var3
# 0     3    20    27
# 1    11     3    13
# 2    25    18    21
# 3    20    20    18

# %%
#iloc --> indekslemeyle secim yapar

# %%
df.iloc[0:3]
# Out:
#    var1  var2  var3
# 0     3    20    27
# 1    11     3    13
# 2    25    18    21

# %%
df.iloc[0,0]
# Out:
# 3

# %%
df.loc[0:3,"var3"]
# Out:
# 0    27
# 1    13
# 2    21
# 3    18
# Name: var3, dtype: int32

# %%
#mutlak bir degisken vericeksek loc kullanılır

# %% [markdown]
# ## Kosullu Eleman

# %%
df
# Out:
#    var1  var2  var3
# 0     3    20    27
# 1    11     3    13
# 2    25    18    21
# 3    20    20    18
# 4    13    17    22
# 5    24     2    21
# 6    28    27     3
# 7     4    14    15
# 8     3    11    27
# 9     2    27    18

# %%
df.var1
# Out:
# 0     3
# 1    11
# 2    25
# 3    20
# 4    13
# 5    24
# 6    28
# 7     4
# 8     3
# 9     2
# Name: var1, dtype: int32

# %%
df[df.var1>15] #kosul calıstırma
# Out:
#    var1  var2  var3
# 2    25    18    21
# 3    20    20    18
# 5    24     2    21
# 6    28    27     3

# %%
df[(df.var1>15) & (df.var3<5)] #ortak satırı aldı
# Out:
#    var1  var2  var3
# 6    28    27     3

# %% [markdown]
# ## join

# %%
import numpy as np
import pandas as pd
m=np.random.randint(1,30,size=(5,3))
df1=pd.DataFrame(m,columns=["var1","var2","var3"])
df1
# Out:
#    var1  var2  var3
# 0    11     5    28
# 1    17    13    12
# 2     8    23    15
# 3    20    10    29
# 4    12     2    24

# %%
df2=df1+99

# %%
df2
# Out:
#    var1  var2  var3
# 0   110   104   127
# 1   116   112   111
# 2   107   122   114
# 3   119   109   128
# 4   111   101   123

# %%
pd.concat([df1,df2],ignore_index=True) #birlesti
# Out:
#    var1  var2  var3
# 0    11     5    28
# 1    17    13    12
# 2     8    23    15
# 3    20    10    29
# 4    12     2    24
# 5   110   104   127
# 6   116   112   111
# 7   107   122   114
# 8   119   109   128
# 9   111   101   123

# %%
df.columns
# Out:
# Index(['var1', 'var2', 'var3'], dtype='object')

# %%
df1.columns=["var1","var2","deg3"]

# %%
df1
# Out:
#    var1  var2  deg3
# 0    11     5    28
# 1    17    13    12
# 2     8    23    15
# 3    20    10    29
# 4    12     2    24

# %%
pd.concat([df1,df2], join="inner")
# Out:
#    var1  var2
# 0    11     5
# 1    17    13
# 2     8    23
# 3    20    10
# 4    12     2
# 0   110   104
# 1   116   112
# 2   107   122
# 3   119   109
# 4   111   101

# %%
#ileri  birlestirme

# %%
import numpy as np
import pandas as pd

df1=pd.DataFrame({'ogrenciler':['ali','veli','fatma'],'bolum':['muhendislik','tıp','isletme']})

# %%
df1
# Out:
#   ogrenciler        bolum
# 0        ali  muhendislik
# 1       veli          tıp
# 2      fatma      isletme

# %%
df2=pd.DataFrame({'ogrenciler':['ali','veli','fatma'],'ortalama':[3,2.4,3.5]})

# %%
df2
# Out:
#   ogrenciler  ortalama
# 0        ali       3.0
# 1       veli       2.4
# 2      fatma       3.5

# %%
pd.merge(df1,df2) #ogrencilere gore birlestirdi
# Out:
#   ogrenciler        bolum  ortalama
# 0        ali  muhendislik       3.0
# 1       veli          tıp       2.4
# 2      fatma      isletme       3.5

# %%
#coktan teke

# %%
df3=pd.merge(df1,df2)

# %%
df4=pd.DataFrame({'ogrenciler':['ali','veli','fatma'],'konu':['goruntu isleme','pediatri','isletme']})

# %%
df4
# Out:
#   ogrenciler            konu
# 0        ali  goruntu isleme
# 1       veli        pediatri
# 2      fatma         isletme

# %%
pd.merge(df3,df4)
# Out:
#   ogrenciler        bolum  ortalama            konu
# 0        ali  muhendislik       3.0  goruntu isleme
# 1       veli          tıp       2.4        pediatri
# 2      fatma      isletme       3.5         isletme
